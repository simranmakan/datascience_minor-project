# %%
#WEB SCRAPING WITH TOPICS LINK

#w3 schools python index
import requests
from bs4 import BeautifulSoup

def get_w3schools_titles():
    url = 'https://www.w3schools.com/python/default.asp'
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')

    menu = soup.find('div', id='leftmenuinnerinner')
    links = menu.find_all('a')
    
    titles = [link.text.strip() for link in links if link.text.strip()]
    return set(titles)
    
#tpoint tech python index
def get_tutorialspoint_titles():
    url = 'https://www.tutorialspoint.com/python/index.htm'
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')

    menu = soup.find('ul', class_='toc chapters')
    links = menu.find_all('a')
    
    titles = [link.text.strip() for link in links if link.text.strip()]
    return set(titles)
    
# Get data
w3_titles = get_w3schools_titles()
tp_titles = get_tutorialspoint_titles()


# Compare
common = w3_titles & tp_titles
only_w3 = w3_titles - tp_titles
only_tp = tp_titles - w3_titles

# Print results
print("🔥 Common Topics:")
for title in sorted(common):
    print("  -", title)

print("\n🌐 Unique to W3Schools:")
for title in sorted(only_w3):
    print("  -", title)

print("\n📘 Unique to TutorialsPoint:")
for title in sorted(only_tp):
    print("  -", title)
# Out:
# 🔥 Common Topics:
#   - Django Tutorial
#   - NumPy Tutorial
#   - Pandas Tutorial
#   - Python Compiler
#   - SciPy Tutorial
#
# 🌐 Unique to W3Schools:
#   - AUC - ROC Curve
#   - AVL Trees
#   - Access Items
#   - Access List Items
#   - Access Set Items
#   - Access Tuples
#   - Add Items
#   - Add List Items
#   - Add Set Items
#   - Add Two Numbers
#   - Assign Multiple Values
#   - Binary Search
#   - Binary Search Trees
#   - Binary Trees
#   - Bootstrap Aggregation
#   - Bubble Sort
#   - Categorical Data
#   - Change Items
#   - Change List Items
#   - Concatenate Strings
#   - Confusion Matrix
#   - Copy Dictionaries
#   - Copy Lists
#   - Counting Sort
#   - Cross Validation
#   - Data Distribution
#   - Decision Tree
#   - Dictionary Exercises
#   - Dictionary Methods
#   - Escape Characters
#   - Format Strings
#   - Getting Started
#   - Global Variables
#   - Graphs
#   - Grid Search
#   - Hash Tables
#   - Hierarchical Clustering
#   - Insertion Sort
#   - Join Lists
# ...

# %%
#WEB SCRAPING WITHOUT TOPICS LINK

import requests
from bs4 import BeautifulSoup

# --- W3Schools ---
def get_w3schools_data():
    url = 'https://www.w3schools.com/python/default.asp'
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    menu = soup.find('div', id='leftmenuinnerinner')
    links = menu.find_all('a')

    w3_data = {}
    for link in links:
        title = link.text.strip()
        href = link.get('href')
        if title and href:
            full_url = f"https://www.w3schools.com{href}"
            w3_data[title] = full_url
    return w3_data


# --- TutorialsPoint ---
def get_tutorialspoint_data():
    url = 'https://www.tutorialspoint.com/python/index.htm'
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')
    menu = soup.find('ul', class_='toc chapters')
    links = menu.find_all('a')

    tp_data = {}
    for link in links:
        title = link.text.strip()
        href = link.get('href')
        if title and href:
            full_url = f"https://www.tutorialspoint.com{href}"
            tp_data[title] = full_url
    return tp_data


# --- Comparison ---
w3_data = get_w3schools_data()
tp_data = get_tutorialspoint_data()

w3_titles = set(w3_data.keys())
tp_titles = set(tp_data.keys())

common = w3_titles & tp_titles
only_w3 = w3_titles - tp_titles
only_tp = tp_titles - w3_titles

# --- Output Results ---
print("🔥 Common Topics (Title + Link):\n")
for title in sorted(common):
    print(f"  - {title} → {w3_data[title]}")

print("\n🌐 Unique to W3Schools:\n")
for title in sorted(only_w3):
    print(f"  - {title} → {w3_data[title]}")

print("\n📘 Unique to TutorialsPoint:\n")
for title in sorted(only_tp):
    print(f"  - {title} → {tp_data[title]}")
# Out:
# 🔥 Common Topics (Title + Link):
#
#   - Django Tutorial → https://www.w3schools.com/django/index.php
#   - NumPy Tutorial → https://www.w3schools.comnumpy/default.asp
#   - Pandas Tutorial → https://www.w3schools.compandas/default.asp
#   - Python Compiler → https://www.w3schools.compython_compiler.asp
#   - SciPy Tutorial → https://www.w3schools.comscipy/index.php
#
# 🌐 Unique to W3Schools:
#
#   - AUC - ROC Curve → https://www.w3schools.compython_ml_auc_roc.asp
#   - AVL Trees → https://www.w3schools.compython_dsa_avltrees.asp
#   - Access Items → https://www.w3schools.compython_dictionaries_access.asp
#   - Access List Items → https://www.w3schools.compython_lists_access.asp
#   - Access Set Items → https://www.w3schools.compython_sets_access.asp
#   - Access Tuples → https://www.w3schools.compython_tuples_access.asp
#   - Add Items → https://www.w3schools.compython_dictionaries_add.asp
#   - Add List Items → https://www.w3schools.compython_lists_add.asp
# ...
